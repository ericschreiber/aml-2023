# %%
import csv
import os

import tqdm

import biosppy.signals.ecg as ecg
import biosppy
import neurokit2 as nk

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp

import hrvanalysis
import heartpy as hp

import sys

sys.path.append("..")
from util import load_base_data


SAMPLING_RATE = 300.0
DATAPATH = "/Users/ericschreiber/dev/ETH/AML/Project_1/aml-2023/task2/data"

# %%
X_train, y_train, X_test = load_base_data()

# %%
def compute_hrv_features(peaks):
    try:
        tdf = hrvanalysis.get_time_domain_features(peaks)
        gf = hrvanalysis.get_geometrical_features(peaks)
        fdf = hrvanalysis.get_frequency_domain_features(peaks)
        pcp = hrvanalysis.get_poincare_plot_features(peaks)
        samp = hrvanalysis.get_sampen(peaks)
    except:
        return [0] * 22

    return [
        tdf["mean_nni"],
        tdf["sdnn"],
        tdf["sdsd"],
        tdf["nni_50"],
        tdf["pnni_50"],
        tdf["nni_20"],
        tdf["pnni_20"],
        tdf["rmssd"],
        tdf["median_nni"],
        tdf["range_nni"],
        tdf["cvsd"],
        tdf["cvnni"],
        tdf["mean_hr"],
        tdf["max_hr"],
        tdf["min_hr"],
        fdf["lf"],
        fdf["hf"],
        fdf["lf_hf_ratio"],
        pcp["sd1"],
        pcp["sd2"],
        pcp["ratio_sd2_sd1"],
        samp["sampen"],
    ]

# %%
def compute_hp_features(ecg):
    try:
        _, measures = hp.process(ecg, SAMPLING_RATE)
    except:
        try:
            _, measures = hp.process(hp.flip_signal(ecg), SAMPLING_RATE)
        except:
            return [0] * 12

    return [
        measures["bpm"],
        measures["ibi"],
        measures["sdnn"],
        measures["sdsd"],
        measures["rmssd"],
        measures["pnn20"],
        measures["pnn50"],
        measures["hr_mad"],
        measures["sd1"],
        measures["sd2"],
        measures["s"],
        np.log10(measures["sd1/sd2"] ** 2),
    ]

# %%
def make_features(ecg):
    cleaned = nk.ecg_clean(ecg, sampling_rate=SAMPLING_RATE)
    _, info = nk.ecg_peaks(ecg_cleaned=cleaned, sampling_rate=SAMPLING_RATE)
    rpeaks = info["ECG_R_Peaks"]
    features = []
    features += compute_hp_features(cleaned)
    features += compute_hrv_features(rpeaks)
    features = np.array(features).flatten()
    return features


def make_features_from_df(df):
    features = []
    for i in tqdm.tqdm(range(len(df))):
        ecg = df.iloc[i].values
        features.append(make_features(ecg))
    numpy = np.array(features)
    df = pd.DataFrame(numpy).reset_index(drop=False)
    df.drop(columns=["index"], inplace=True)
    df.index.name = "id"

    return df

# %%
features_X_train = make_features_from_df(X_train)
# Out:
#   0%|          | 0/5117 [00:00<?, ?it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1485 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9254 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9582 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9090 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9345 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   0%|          | 5/5117 [00:00<01:47, 47.41it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9776 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9003 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9301 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 526 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14293 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9476 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9426 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   0%|          | 12/5117 [00:00<01:27, 58.09it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9508 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 7561 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9348 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9537 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 13736 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 148, using nperseg = 148
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9468 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9649 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   0%|          | 19/5117 [00:00<01:22, 61.56it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14312 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 103, using nperseg = 103
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9609 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9571 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9451 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 5651 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9401 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9509 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|          | 26/5117 [00:00<01:21, 62.14it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 7933 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9405 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 11908 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14969 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 108, using nperseg = 108
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9705 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9588 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9806 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|          | 33/5117 [00:00<01:18, 64.75it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1249 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9556 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9455 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9483 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9275 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1645 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9636 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|          | 40/5117 [00:00<01:21, 62.64it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1685 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9241 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1418 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9237 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1238 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9891 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9174 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|          | 47/5117 [00:00<01:22, 61.77it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14242 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 79, using nperseg = 79
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9820 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 858 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9444 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9169 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9676 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9707 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|          | 54/5117 [00:00<01:18, 64.09it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 8796 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9393 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9461 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9467 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9661 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9259 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9367 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9456 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|          | 62/5117 [00:00<01:15, 66.73it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9236 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9348 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 536 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9068 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9364 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9238 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9219 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|▏         | 69/5117 [00:01<01:18, 63.94it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 13119 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 153, using nperseg = 153
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9315 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 11869 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9488 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9837 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9613 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9552 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   1%|▏         | 76/5117 [00:01<01:18, 64.15it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9047 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9434 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 5334 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 6940 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9479 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9849 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 5373 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   2%|▏         | 83/5117 [00:01<01:18, 64.00it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9257 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9431 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14377 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 81, using nperseg = 81
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9584 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9298 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9675 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9449 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   2%|▏         | 90/5117 [00:01<01:19, 63.63it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 8938 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9440 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 683 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 10757 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9618 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9546 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14333 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 133, using nperseg = 133
#   warnings.warn('nperseg = {0:d} is greater than input length '
#   2%|▏         | 97/5117 [00:01<01:21, 61.94it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 5414 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9208 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9951 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1623 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 452 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 12198 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 204, using nperseg = 204
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 13617 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 134, using nperseg = 134
#   warnings.warn('nperseg = {0:d} is greater than input length '
#   2%|▏         | 104/5117 [00:01<01:20, 62.41it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9197 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9118 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 350 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9212 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 13783 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 95, using nperseg = 95
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1473 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9966 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   2%|▏         | 111/5117 [00:01<01:19, 62.69it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9763 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9486 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9891 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1646 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9747 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9630 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1488 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   2%|▏         | 118/5117 [00:01<01:18, 63.83it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9535 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9294 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9430 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9345 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9850 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 7842 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9800 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   2%|▏         | 125/5117 [00:01<01:16, 65.00it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9629 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9552 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9692 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 12165 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 247, using nperseg = 247
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9732 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9744 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1036 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
#   3%|▎         | 132/5117 [00:02<01:17, 64.12it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9331 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9223 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9406 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9414 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 5733 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1285 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9318 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   3%|▎         | 139/5117 [00:02<01:17, 64.00it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9780 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9804 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9318 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9444 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1838 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9233 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9494 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   3%|▎         | 146/5117 [00:02<01:15, 65.69it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9331 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9262 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9768 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9668 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9266 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9206 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1126 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   3%|▎         | 153/5117 [00:02<01:17, 64.26it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9246 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9417 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14848 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 73, using nperseg = 73
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 151 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 6449 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9466 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9272 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   3%|▎         | 160/5117 [00:02<01:16, 64.82it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 8289 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9251 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9649 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9398 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9266 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9365 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9506 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9426 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#   3%|▎         | 168/5117 [00:02<01:14, 66.84it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9529 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9482 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9611 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9828 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# ...
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9298 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9417 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 717 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1780 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9413 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9663 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#  99%|█████████▉| 5065/5117 [01:19<00:00, 61.09it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9631 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9072 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9579 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9530 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9240 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9449 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9306 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#  99%|█████████▉| 5072/5117 [01:19<00:00, 61.47it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9668 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 11058 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 3956 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9438 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9317 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9468 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9500 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#  99%|█████████▉| 5079/5117 [01:19<00:00, 62.33it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 7031 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1529 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9767 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9295 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9510 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9599 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9468 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
#  99%|█████████▉| 5086/5117 [01:19<00:00, 60.89it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 10817 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9623 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 11954 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 244, using nperseg = 244
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 4107 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9714 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9623 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 14546 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 66, using nperseg = 66
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9457 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# 100%|█████████▉| 5094/5117 [01:19<00:00, 64.91it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9465 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1335 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9680 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 1154 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 775 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9683 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 12071 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# 100%|█████████▉| 5101/5117 [01:20<00:00, 63.55it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9736 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9561 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9307 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9584 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9483 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9044 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9561 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# 100%|█████████▉| 5108/5117 [01:20<00:00, 63.99it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 8635 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9465 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9271 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9409 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 12637 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/scipy/signal/_spectral_py.py:1999: UserWarning: nperseg = 256 is greater than input length  = 247, using nperseg = 247
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9545 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9333 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# 100%|█████████▉| 5115/5117 [01:20<00:00, 61.67it/s]/Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9467 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/neurokit2/ecg/ecg_clean.py:101: NeuroKitWarning: There are 9677 missing data points in your signal. Filling missing values by using the forward filling method.
#   warn(
# 100%|██████████| 5117/5117 [01:20<00:00, 63.69it/s]

# %%
features_X_train
# Out:
#               0           1           2           3           4         5   \
# id
# 0     148.323219  404.521964  138.731051   33.087106  267.346356  1.000000
# 1     245.702730  244.197531  145.246376  126.019165  228.147397  0.944444
# 2     141.176471  425.000000  163.952907   40.945613  237.993153  1.000000
# 3     304.061339  197.328605   88.688207  101.899254  140.948600  0.828571
# 4     245.914198  243.987539  116.049045   97.557653  186.549013  0.971154
# ...          ...         ...         ...         ...         ...       ...
# 5112  330.324910  181.639344  126.060706  104.365539  182.836589  0.907407
# 5113  266.647490  225.016181  159.757687  130.676988  244.340757  0.948454
# 5114  207.201178  289.573643  157.818458  122.964934  264.067442  0.964286
# 5115  146.670413  409.080460  152.835014   53.769290  299.544883  1.000000
# 5116  305.124836  196.640827  117.911408  101.715142  179.748502  0.928571
#
#             6           7           8           9   ...         24  \
# id                                                  ...
# 0     0.992063  120.000000  189.042240   46.871917  ...  27.321386
# 1     0.861111   76.666667  161.009174  135.155882  ...  32.087007
# 2     1.000000  130.000000  163.446673   24.062675  ...  33.602249
# 3     0.507143   23.333333   99.665705   73.760091  ...  34.480877
# 4     0.894231   70.000000  131.909634   93.435944  ...  33.618730
# ...        ...         ...         ...         ...  ...        ...
# 5112  0.759259   96.666667  129.029829  120.681238  ...  28.850907
# 5113  0.876289  116.666667  172.693781  143.700555  ...  42.205843
# 5114  0.940476  116.666667  186.722106  118.835376  ...  40.082699
# 5115  0.980769   31.666667  211.809980   57.463703  ...  42.687403
# 5116  0.809524   66.666667  127.101186  107.325535  ...  30.365351
#
#               25         26          27        28          29         30  \
# id
# 0     588.235294   3.690945  200.551149  0.223638  896.766297  13.869757
# 1     310.880829   7.082989  613.311336  0.834230  735.182430   9.338994
# 2     310.880829   7.472911  905.560707  1.186693  763.095814   7.619007
# 3     560.747664   6.960557  271.824481  1.355169  200.583470  15.518064
# 4     377.358491   7.122507  333.185735  4.071303   81.837607  14.675273
# ...          ...        ...         ...       ...         ...        ...
# 5112  108.892922  11.822660  774.784060  7.102584  109.084817  67.283219
# 5113  540.540541   7.360157  625.990190  0.775245  807.473567   3.036870
# 5114  468.750000   7.133516  703.109156  0.866982  810.984441  20.209886
# 5115  582.524272   7.275373  630.753697  0.940980  670.315891   6.037517
# 5116  262.008734   7.470120  356.319268  0.450950  790.151939   7.736869
#
#                31           32        33
# id
# 0     6761.671334   487.511877  0.005063
# 1     3508.869917   375.722477  0.059423
# 2     3366.650149   441.875213 -0.000000
# 3     3529.170511   227.423374  0.021693
# 4     3542.203067   241.372210  0.012121
# ...           ...          ...       ...
# 5112  1944.244673    28.896428  0.057158
# 5113  3432.091437  1130.140969 -0.000000
# 5114  3575.335004   176.910201  0.038466
# 5115  3473.115641   575.255618 -0.000000
# 5116  3282.572524   424.276600 -0.000000
#
# [5117 rows x 34 columns]

# %%
# How many infs
print(f"Number of infs: {np.sum(np.isinf(features_X_train), axis=0).sum()}")
# Which columns have infs
cols_with_infs = np.where(np.isinf(features_X_train))[1]
cols_with_infs_unique = np.unique(cols_with_infs)
print(f"Columns with infs: {len(cols_with_infs_unique)}")
print(
    f"biggest pos value except inf: {np.max(features_X_train[features_X_train != np.inf].max())}"
)
print(f"biggest neg value: {np.min(features_X_train).min()}")
biggest_pos = np.max(features_X_train[features_X_train != np.inf].max())
biggest_neg = np.min(features_X_train).min()
# Replace infs with biggest pos value
features_X_train[features_X_train == np.inf] = biggest_pos
# Replace -infs with biggest neg value
features_X_train[features_X_train == -np.inf] = biggest_neg
# Out:
# Number of infs: 246
# Columns with infs: 1
# biggest pos value except inf: 785327.1102283916
# biggest neg value: -2.247994842224999
# /Users/ericschreiber/miniconda3/envs/ml/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
X_train_save_path = os.path.join(DATAPATH, "feature_extraction/hrv_X_train.csv")
features_X_train.to_csv(X_train_save_path, index=True)

# %% [markdown]
# # X Test

# %%
# test_features = make_features_from_df(X_test)

# How many infs
print(f"Number of infs: {np.sum(np.isinf(test_features), axis=0).sum()}")
# Which columns have infs
cols_with_infs = np.where(np.isinf(test_features))[1]
cols_with_infs_unique = np.unique(cols_with_infs)
print(f"Columns with infs: {len(cols_with_infs_unique)}")
print(
    f"biggest pos value except inf: {np.max(test_features[test_features != np.inf].max())}"
)
print(
    f"biggest neg value excpet inf : {np.min(test_features[test_features != -np.inf]).min()}"
)
biggest_pos = np.max(test_features[test_features != np.inf].max())
biggest_neg = np.min(test_features[test_features != -np.inf]).min()
# Replace infs with biggest pos value
test_features[test_features == np.inf] = biggest_pos
# Replace -infs with biggest neg value
test_features[test_features == -np.inf] = biggest_neg
# Out:
# Number of infs: 1
# Columns with infs: 1
# biggest pos value except inf: 1419764.0845090873
# biggest neg value excpet inf : -2.235093400946307

# %%
X_test_save_path = os.path.join(DATAPATH, "feature_extraction/hrv_X_test.csv")
test_features.to_csv(X_test_save_path, index=True)
