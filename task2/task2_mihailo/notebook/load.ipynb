# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
import biosppy.signals.ecg as ecg
import json

sys.path.append('..')
from util import load_base_data

plt.rcParams['figure.figsize'] = [6, 5]
SAMPLING_RATE = 300

# %%
# %%time
X_train, y_train = load_base_data(just_train=True, standard=True, flip=False)
# Out:
# CPU times: user 14.3 s, sys: 2.07 s, total: 16.3 s
# Wall time: 17.3 s

# %%
# %%time
X_train_flipped_norm, in_flipped_norm = load_base_data(just_train=True, normal=True, flip=True)

# %%
X_train[:21]
# Out:
#           x0        x1        x2        x3        x4        x5        x6  \
# id
# 0  -0.203345 -0.166647 -0.139124 -0.120775 -0.084077 -0.065728 -0.029031
# 1  -0.318997  0.718533  1.720038  2.735953  3.723047  4.530015  5.120831
# 2  -0.248745 -0.258787 -0.263808 -0.273850 -0.283892 -0.288913 -0.298954
# 3   1.474936  1.503172  1.526702  1.559643  1.606703  1.681998  1.766705
# 4   1.094774  1.232391  1.332476  1.426307  1.470094  1.501371  1.526392
# 5  -3.105824 -3.001581 -2.905356 -2.744982 -2.512439 -2.287915 -2.087447
# 6   0.008809  0.118350  0.215005  0.292328  0.382538  0.479192  0.575846
# 7  -1.906035 -1.520899 -1.194604 -1.012734 -0.884355 -0.782722 -0.681089
# 8   5.005091  6.425867  7.152970  6.701664  5.021806  2.606487  0.099235
# 9  -0.567731 -0.583540 -0.599348 -0.615157 -0.625696 -0.625696 -0.615157
# 10 -0.112390 -0.120994 -0.129599 -0.138203 -0.146807 -0.155412 -0.164016
# 11  0.364726  0.364726  0.357809  0.350892  0.337057  0.309387  0.274800
# ...

# %%
X_train_flipped_norm[:21]

# %%
def flip(df, flipped_indices):
    df_copy = df.copy()
    df_copy.iloc[flipped_indices] = -1 * df_copy.iloc[flipped_indices]
    return df_copy

# %%
def normalize(df):
    df_normed = df.sub(df.min(axis=1),axis=0).divide(df.max(axis=1) - df.min(axis=1), axis=0)
    df_normed_flipped = 1 - df_normed
    return df_normed

# %%
# %%time
normalize(X_test[:10])

# %%
flip(X_test[:10], [0,1,2,3])

# %%
X_test[:10]

# %%
with open('../outliers/train/flipped.json') as json_file:
    flipped_indices = json.load(json_file)
type(flipped_indices)
