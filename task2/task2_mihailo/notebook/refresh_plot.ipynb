# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output

# %%
x = range(20)
y = [i**2 for i in X]

# %%
l = []
for i in range(5):
    plt.plot(X, y + 10*np.random.randn(len(y)))
    plt.show()
    choice = input()
    if choice == 'y':
        l.append(i)
    clear_output(wait=True)
print(l)
